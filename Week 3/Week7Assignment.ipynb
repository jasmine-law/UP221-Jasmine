# %% [markdown]
# ## **Week 7 Assignment**
#
# In this assignment, I cleaned up the bar graph and maps from the midterm (and made sure they were actually functioning this time).
#
# I wanted to make the bar graph and choropleth map make a little more sense by getting the youth percentage by neighborhood, rather than census tract. I also wanted to add markers to the folium choropleth map that display the school locations as well to answer the question if schools were even located in neighborhoods with a higher percentage of children.

# %%
#libraries
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import numpy as np
import branca.colormap as cm
import plotly.express as px
import folium

# %% [markdown]
# ### Data and Data Cleaning

# %%
#data
ag = pd.read_csv('data/sfpop2.csv')
dict_for_FIPS = {
    'GEO_ID': str,
    }
ag = pd.read_csv(
    'data/sfpop2.csv',
    dtype=dict_for_FIPS
)

# %%
# process the population data

ag = pd.read_csv(
    'data/sfpop2.csv',
    dtype={'GEO_ID':str}
)
ag = ag[["GEO_ID", "NAME", "S0601_C01_001E", "S0601_C01_003E"]]

ag = ag.rename(
    columns={
        'GEO_ID': 'FIPS', 
        'NAME' : 'Tract',
        'S0601_C01_001E' : 'Total tract pop',
        'S0601_C01_003E' : 'Total Youth pop'
    }
) 
ag = ag.drop(labels=0, axis=0)
# Drop percent youth with no data, marked as "-"
ag = ag[ag['Total Youth pop'] != '-']
# Change it to numeric
ag['Total Youth pop'] = ag['Total Youth pop'].astype(float)
ag['Total tract pop'] = ag['Total tract pop'].astype(float)

# %%
#converting percent youth by tract into a decimal point
ag['Total Youth pop'] = ag['Total Youth pop']/100

# %%
ag['Total Youth pop'] = ag['Total tract pop'] * ag['Total Youth pop']

# %%
# process the neighborhoods data

neighborhoods = pd.read_csv(
    'data/SFCensusTractstoNeighborhoods.csv',
    dtype={'geoid':str}
)

neighborhoods = neighborhoods[['neighborhoods_analysis_boundaries', 'geoid']]

neighborhoods = neighborhoods.rename(
    columns={'neighborhoods_analysis_boundaries': 'neighborhoods', 
        'geoid': 'FIPS'}
)

# %%
# process tracts data
tracts=gpd.read_file('data/Census 2020_ Tracts for San Francisco.geojson')
tracts = tracts[['geoid','geometry']]
tracts.columns = ['FIPS',
                  'geometry'
                 ]
#getting rid of Farallone Islands
tracts.drop([35,88,205], axis=0, inplace=True)

# %%
# merge all data. Output should be a GeoDataFrame
ag_merged1 = ag.merge(neighborhoods,on="FIPS")
ag_merged = ag_merged1.merge(tracts, on="FIPS")
# force it
ag_merged = gpd.GeoDataFrame(ag_merged, geometry='geometry')

# %% [markdown]
# ### Bar Graph of Youth in San Francisco by Neighborhood

# %%
#test plot
fig2 = px.bar(ag_merged,
              x='neighborhoods',
              y='Total Youth pop',
              title='Number of Youth Ages 5 to 17 by Neighborhood',
              barmode='group',
              color_discrete_sequence=['lightseagreen'],
              height=700
              )
fig2
# Out:
# <div>                            <div id="96e88827-397f-49ed-9c67-13d0ff5d03e0" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96e88827-397f-49ed-9c67-13d0ff5d03e0")) {                    Plotly.newPlot(                        "96e88827-397f-49ed-9c67-13d0ff5d03e0",                        [{"alignmentgroup":"True","hovertemplate":"neighborhoods=%{x}\u003cbr\u003eTotal Youth pop=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"lightseagreen","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["North Beach","North Beach","Russian Hill","Russian Hill","Russian Hill","North Beach","North Beach","Financial District\u002fSouth Beach","North Beach","Chinatown","Chinatown","Nob Hill","Russian Hill","Russian Hill","Russian Hill","Russian Hill","Nob Hill","Nob Hill","Nob Hill","Chinatown","Financial District\u002fSouth Beach","Chinatown","Nob Hill","Nob Hill","Nob Hill","Nob Hill","Nob Hill","Tenderloin","Tenderloin","Tenderloin","Tenderloin","Tenderloin","Tenderloin","Tenderloin","Tenderloin","Tenderloin","Tenderloin","Tenderloin","Tenderloin","Marina","Marina","Marina","Marina","Marina","Marina","Marina","Marina","Marina","Pacific Heights","Pacific Heights","Pacific Heights","Presidio Heights","Pacific Heights","Pacific Heights","Pacific Heights","Western Addition","Pacific Heights","Pacific Heights","Pacific Heights","Presidio Heights","Presidio Heights","Japantown","Lone Mountain\u002fUSF","Lone Mountain\u002fUSF","Lone Mountain\u002fUSF","Western Addition","Western Addition","Western Addition","Western Addition","Western Addition","Western Addition","Hayes Valley","Hayes Valley","Hayes Valley","Lone Mountain\u002fUSF","Haight Ashbury","Haight Ashbury","Haight Ashbury","Hayes Valley","Hayes Valley","Castro\u002fUpper Market","Castro\u002fUpper Market","Haight Ashbury","Haight Ashbury","South of Market","South of Market","South of Market","Mission","South of Market","South of Market","South of Market","Treasure Island","South of Market","Mission","Mission","Mission","Mission","Castro\u002fUpper Market","Castro\u002fUpper Market","Twin Peaks","Castro\u002fUpper Market","Castro\u002fUpper Market","Castro\u002fUpper Market","Mission","Mission","Mission","Mission","Mission","Mission","Noe Valley","Noe Valley","Noe Valley","Noe Valley","Noe Valley","Noe Valley","Glen Park","Glen Park","Potrero Hill","Potrero Hill","Potrero Hill","Mission","Mission","Mission","Mission","Mission","Mission","Bayview Hunters Point","Bayview Hunters Point","Bayview Hunters Point","Bayview Hunters Point","Bayview Hunters Point","Bayview Hunters Point","Bayview Hunters Point","Bernal Heights","Bernal Heights","Bernal Heights","Bernal Heights","Bernal Heights","Bernal Heights","Outer Mission","Outer Mission","Excelsior","Portola","Portola","Portola","Portola","Excelsior","Excelsior","Excelsior","Excelsior","Outer Mission","Outer Mission","Outer Mission","Excelsior","Excelsior","Excelsior","Visitacion Valley","Visitacion Valley","Visitacion Valley","Visitacion Valley","Inner Sunset","Inner Sunset","Inner Sunset","Inner Sunset","Inner Sunset","Inner Sunset","West of Twin Peaks","Twin Peaks","West of Twin Peaks","West of Twin Peaks","West of Twin Peaks","West of Twin Peaks","West of Twin Peaks","West of Twin Peaks","Oceanview\u002fMerced\u002fIngleside","Oceanview\u002fMerced\u002fIngleside","Oceanview\u002fMerced\u002fIngleside","Oceanview\u002fMerced\u002fIngleside","Oceanview\u002fMerced\u002fIngleside","Oceanview\u002fMerced\u002fIngleside","Sunset\u002fParkside","Sunset\u002fParkside","Sunset\u002fParkside","Sunset\u002fParkside","Sunset\u002fParkside","Sunset\u002fParkside","Sunset\u002fParkside","Sunset\u002fParkside","Sunset\u00 ...

# %% [raw]
# This chart displays neighborhoods where we have the highest raw numbers of youth. We can see that the Sunset, Outer Richmond, and Mission tend to have many children.
#
# However, realizing this now, this histogram does not tell an accurate story about the kids in San Francisco. This histogram takes in the percentages of youth per census tract and stacks them into their designated neighborhood, but it does not account for *density*.

# %% [markdown]
# ### Cleaning up more data to reflect youth population by neighborhood across the city

# %%
# summing up youth population by neighborhood
ag_merged['neighborhoods'] = ag_merged['neighborhoods'].astype(str)
ag_merged['Total Youth pop'] = pd.to_numeric(ag_merged['Total Youth pop'], errors = 'coerce')
ag_merged['Total tract pop'] = pd.to_numeric(ag_merged['Total tract pop'], errors = 'coerce')

#group by neighborhood and sum youth population
neighborhood_sums = ag_merged.groupby('neighborhoods', as_index=False)['Total Youth pop'].sum()

#group by neighborhood and sum each tract population
totalpop_sums = ag_merged.groupby('neighborhoods', as_index=False)['Total tract pop'].sum()

#merging the dataframes
neighborhood_sums = neighborhood_sums.merge(totalpop_sums, on='neighborhoods')

# rename columns
neighborhood_sums.columns = ['neighborhoods', 'youth population', 'neighborhood population']

neighborhood_sums.head()
# Out:
#            neighborhoods  youth population  neighborhood population
# 0  Bayview Hunters Point          6473.613                  40495.0
# 1         Bernal Heights          2897.052                  24767.0
# 2    Castro/Upper Market          1604.797                  22623.0
# 3              Chinatown          1038.350                  13693.0
# 4              Excelsior          5119.668                  38846.0

# %%
total_citypop = neighborhood_sums['neighborhood population'].sum()
print('Total SF population:', total_citypop)
# Out:
# Total SF population: 851036.0

# %%
# creating another column on the dataframe
neighborhood_sums['youth percentage'] = (
    neighborhood_sums['youth population'] / total_citypop
) * 100
neighborhood_sums.head()
# Out:
#            neighborhoods  youth population  neighborhood population  \
# 0  Bayview Hunters Point          6473.613                  40495.0
# 1         Bernal Heights          2897.052                  24767.0
# 2    Castro/Upper Market          1604.797                  22623.0
# 3              Chinatown          1038.350                  13693.0
# 4              Excelsior          5119.668                  38846.0
#
#    youth percentage
# 0          0.760674
# 1          0.340415
# 2          0.188570
# 3          0.122010
# 4          0.601581

# %%
neighbor_sums = px.bar(neighborhood_sums,
              x='neighborhoods',
              y='youth percentage',
              title='Percent of youth per neighborhood in San Francisco',
              barmode='group',
              color_discrete_sequence=['lightseagreen'],
              height=700
              )
neighbor_sums
# Out:
# <div>                            <div id="15421166-8e96-4e5f-8714-75a813282c77" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15421166-8e96-4e5f-8714-75a813282c77")) {                    Plotly.newPlot(                        "15421166-8e96-4e5f-8714-75a813282c77",                        [{"alignmentgroup":"True","hovertemplate":"neighborhoods=%{x}\u003cbr\u003eyouth percentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"lightseagreen","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bayview Hunters Point","Bernal Heights","Castro\u002fUpper Market","Chinatown","Excelsior","Financial District\u002fSouth Beach","Glen Park","Golden Gate Park","Haight Ashbury","Hayes Valley","Inner Richmond","Inner Sunset","Japantown","Lakeshore","Lincoln Park","Lone Mountain\u002fUSF","Marina","McLaren Park","Mission","Mission Bay","Nob Hill","Noe Valley","North Beach","Oceanview\u002fMerced\u002fIngleside","Outer Mission","Outer Richmond","Pacific Heights","Portola","Potrero Hill","Presidio","Presidio Heights","Russian Hill","Seacliff","South of Market","Sunset\u002fParkside","Tenderloin","Treasure Island","Twin Peaks","Visitacion Valley","West of Twin Peaks","Western Addition"],"xaxis":"x","y":[0.7606744015529308,0.3404147415620491,0.18856981373290904,0.12201011473075168,0.6015806616876372,0.07296577348079282,0.14031921093819766,0.0,0.15344333259697593,0.08555748522976701,0.2489673762332028,0.25382710014617477,0.0034856339802311538,0.10242128417599257,0.0,0.13186198938705296,0.1926267513947706,0.0,0.5744520795830024,0.12453715236488234,0.06817032416960035,0.2607686396345161,0.103779628593855,0.33387776780300715,0.33421277125762017,0.5546770054380779,0.16753580342077184,0.21654078088353487,0.1317710414130542,0.06269064998425448,0.13582269140200884,0.06173569625726762,0.04690283372266273,0.15242610183352995,1.0642291277924787,0.268198055076401,0.047166982360323184,0.07085046931034646,0.3024491325866356,0.5839399273356238,0.1951203004338242],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colo ...

# %% [markdown]
# This graph more accurately reflects the concentration of youth in the city by neighborhood. It shows that compared to the city's population, the Sunset/Parkside, Bayview Hunters Point, and Excelsior neighborhoods have the most children in the city. This helps inform us as to where

# %% [markdown]
# ## Interactive Choropleth Map

# %%
# merging neighborhood_sums and ag_merged
ag_merged = ag_merged.merge(
    neighborhood_sums[['neighborhoods', 'youth percentage']],
    on='neighborhoods',
    how='left'
)

# %% [markdown]
# ### Cleaning school data to add to the Choropleth

# %%
# school location data
schools = gpd.read_file('data/Filtered_Schools.csv')
schools = schools[schools['CCSF Entity'].str.contains('SFUSD')]
schools = schools[schools['Grade Range'].str.contains('9-12')]
schools = schools[['Campus Name', 'Campus Address', 'Location 1']]
schools = schools.drop(index=38)
schools.head(10)
# Out:
#                                      Campus Name  \
# 11       Marshall, Thurgood Marshall High School
# 90   Burton, Phillip And Sala Burton High School
# 92     Washington, George Washington High School
# 135         Lincoln, Abraham Lincoln High School
# 174         Life Learning Academy Charter School
# 194    Gateway High School / Kipp Sf Bay Academy
# 195                          Galileo High School
# 219                           Balboa High School
# 284               City Arts And Tech High School
# 286                     Independence High School
#
#                                  Campus Address                    Location 1
# 11      45 CONKLING ST, San Francisco, CA 94124  CA\n(37.736309, -122.401649)
# 90      400 MANSELL ST, San Francisco, CA 94134  CA\n(37.721546, -122.406555)
# 92        600 32ND AVE, San Francisco, CA 94121  CA\n(37.777905, -122.491013)
# 135      2162 24TH AVE, San Francisco, CA 94116   CA\n(37.746594, -122.48024)
# 174      651 8TH TI ST, SAN FRANCISCO, CA 94130  CA\n(37.825512, -122.367996)
# 194      1430 SCOTT ST, San Francisco, CA 94115  CA\n(37.783264, -122.436691)
# 195  1150 FRANCISCO ST, San Francisco, CA 94109  CA\n(37.803791, -122.424149)
# 219    1000 CAYUGA AVE, San Francisco, CA 94112  CA\n(37.721142, -122.441399)
# 284  325 LA GRANDE AVE, San Francisco, CA 94112  CA\n(37.718784, -122.424667)
# 286      1350 07TH AVE, San Francisco, CA 94122  CA\n(37.763226, -122.463585)

# %%
schools[['latitude', 'longitude']] = schools['Location 1'].str.extract(r'\(([^,]+), ([^,]+)\)').astype(float)
schools.head()
# Out:
#                                      Campus Name  \
# 11       Marshall, Thurgood Marshall High School
# 90   Burton, Phillip And Sala Burton High School
# 92     Washington, George Washington High School
# 135         Lincoln, Abraham Lincoln High School
# 174         Life Learning Academy Charter School
#
#                               Campus Address                    Location 1  \
# 11   45 CONKLING ST, San Francisco, CA 94124  CA\n(37.736309, -122.401649)
# 90   400 MANSELL ST, San Francisco, CA 94134  CA\n(37.721546, -122.406555)
# 92     600 32ND AVE, San Francisco, CA 94121  CA\n(37.777905, -122.491013)
# 135   2162 24TH AVE, San Francisco, CA 94116   CA\n(37.746594, -122.48024)
# 174   651 8TH TI ST, SAN FRANCISCO, CA 94130  CA\n(37.825512, -122.367996)
#
#       latitude   longitude
# 11   37.736309 -122.401649
# 90   37.721546 -122.406555
# 92   37.777905 -122.491013
# 135  37.746594 -122.480240
# 174  37.825512 -122.367996

# %%
m = folium.Map(location=[37.7619, -122.4194], 
               zoom_start = 12,
               tiles='CartoDB positron', 
               attribution='CartoDB')

folium.Choropleth(
                  geo_data=ag_merged, # geo data
                  data=ag_merged, # data          
                  key_on='feature.properties.FIPS', # key, or merge column
                  columns=['FIPS', 'youth percentage'], # [key, value]
                  fill_color='YlGnBu',
                  line_weight=0.1, 
                  fill_opacity=0.8,
                  line_opacity=0.5, # line opacity (of the border)
                  legend_name='Population School-Age Youth').add_to(m) # name on the legend color bar

# %%
style_function = lambda x: {'fillColor': '#ffffff', 
                            'color':'#000000', 
                            'fillOpacity': 0.1, 
                            'weight': 0.1}
highlight_function = lambda x: {'fillColor': '#000000', 
                                'color':'#000000', 
                                'fillOpacity': 0.50, 
                                'weight': 0.1}
TRACTS = folium.features.GeoJson(
    ag_merged,
    style_function=style_function, 
    control=False,
    highlight_function=highlight_function, 
    tooltip=folium.features.GeoJsonTooltip(
        fields=['FIPS','neighborhoods','youth percentage'],
        aliases=['FIPS Code: ','Neighborhood: ','School-age youth population in %: '],
        style=("background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;") 
    )
)
m.add_child(TRACTS)
m.keep_in_front(TRACTS)
folium.LayerControl().add_to(m)

for index, row in schools.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Campus Name'],
        icon=folium.Icon(color='blue', icon='school')
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_511b55f36f8ad6f59be024d2792c9ecb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#                             background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_511b55f36f8ad6f59be024d2792c9ecb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_511b55f36f8ad6f59be024d2792c9ecb = L.map(
#                 &quot;map_511b55f36f8ad6f59be024d2792c9ecb&quot;,
#                 {
#                     center: [37.7619, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;attribution&quot;: &quot;CartoDB&quot;,
# }
#
#                 }
#             );
#
#
#             function objects_in_front() {
#                     geo_json_9f1f0d9ade4f0e7c942440b074e77253.bringToFront();
#             };
#             map_511b55f36f8ad6f59be024d2792c9ecb.on(&quot;overlayadd&quot;, objects_in_front);
#             $(document).ready(objects_in_front);
#
#
#
#             var tile_layer_46962f391a47c3545d750fb4cd5c4b00 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46962f391a47c3545d750fb4cd5c4b00.addTo(map_511b55f36f8ad6f59be024d2792c9ecb);
#
#
#             var choropleth_3d1a1fa4b3eb16e0f762b139427b4bf1 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_51531ecaa1d837dc932e1cddb6c89dce_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;48&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;54&quot;: case &quot;56&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;71&quot;: case &quot;72&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;79&quot;: case &quot;82&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;88&quot;: case &quot;89&quot;: case &quot;90&quot;: case &quot;91&quot;: case &quot;92&quot;: case &quot;99&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;119&quot;: case &quot;167&quot;: case &quot;190&quot;: case &quot;191&quot;: case &quot;192&quot;: case &quot;204&quot;: case &quot;216&quot;: case &quot;217&quot;: case &quot;219&quot;: case &quot;220&quot;: case &quot;221&quot;: case &quot;223&quot;: case &quot;224&quot;: case &quot;226&quot;: case &quot;227&quot;: case &quot;228&quot;: case &quot;229&quot;: case &quot;230&quot;: case &quot;231&quot;: case &quot;232&quot;: case &quot;233&quot;: case &quot;234&quot;: case &quot;235&quot;: case &quot;236&quot;: case &quot;237&quot;: case &quot;238&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 0.1};
#                 case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;47&quot;: case &quot;55&quot;: case &quot;65&quot;: case &quot;66&qu

# %% [markdown]
# Where are all the children located in San Francisco? Are schools located in neighborhoods with higher concentrations of children?
#
# The map shows that most children are located in the Sunset/Parkside neighborhood on the west, and in the Bayview Hunters Point District on the east. Other top neighborboods with children include the Mission, Excelsior, Outer Richmond, and West of Twin Peaks neighborhoods.
#
# Despite the large concentration of children in the Sunset/Parkside, there are only 2 high schools on the westside of the city. On the contrast, there is a cluster of schools in the Mission neighborhoods and center of San Francisco (Western Addition/USF), despite not having a large concentration of children there. With an open enrollment system where any student is allowed to enroll anywhere in the city, some school commutes are bound to be messy, but we can see from our map where most student commutes begin.
#
# This map still has limitations. Although it lists out every high school available for open enrollment within SFUSD, it does not acknowledge the variety of school sizes. Some schools are bound to have larger or smaller capacities for enrollment (such as having a school enrollment of 1,800 students compared to 100) which are not reflected in this visualization.
